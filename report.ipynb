# %%
from pathlib import Path
import json,sys

root=Path(r"C:\\Users\\prach\\Downloads\\THE-DATA0SCIENCE-PROJECT")
sys.path.insert(0,str(root/"src"))
from ds0 import summary

root

# %%
cap=(summary(root)
     .load()
     .clean()
     .make_features()
     .make_ts()
     .fit_xgb()
     .fit_xgb_ts()
     .fit_tf_ts()
     .fit_torch_ts())
cap.res

# %%
p=root/"07_model_output"/"metrics.json"
print(p)
print(p.read_text(encoding="utf-8")[:1200])
